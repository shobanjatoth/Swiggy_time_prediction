# %%
import pandas as pd
import numpy as np

from sklearn.feature_selection import mutual_info_regression
from sklearn.ensemble import RandomForestRegressor
from sklearn.inspection import permutation_importance
from sklearn.linear_model import Lasso
from sklearn.preprocessing import StandardScaler

from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
df = pd.read_csv(r"D:\Swiggy_Time_prediction\Data\encoded.csv")

# %%
df.drop(columns=["Unnamed: 0","city_name"],inplace=True)

# %%
df.columns
# Out:
# Index(['age', 'ratings', 'restaurant_latitude', 'restaurant_longitude',
#        'delivery_latitude', 'delivery_longitude', 'traffic',
#        'vehicle_condition', 'multiple_deliveries', 'festival', 'city_type',
#        'time_taken', 'order_day', 'order_month', 'order_day_of_week',
#        'is_weekend', 'pickup_time_minutes', 'order_time_hour',
#        'order_time_of_day', 'distance', 'weather_fog', 'weather_sandstorms',
#        'weather_stormy', 'weather_sunny', 'weather_windy',
#        'type_of_order_drinks', 'type_of_order_meal', 'type_of_order_snack',
#        'type_of_vehicle_electric_scooter', 'type_of_vehicle_motorcycle',
#        'type_of_vehicle_scooter'],
#       dtype='str')

# %%
X = df.drop(columns=["time_taken"])
y = df["time_taken"]

# %%
numerical_features = X.select_dtypes(include=["int64", "float64"]).columns.tolist()
categorical_features = X.select_dtypes(include=["object", "bool"]).columns.tolist()

numerical_features, categorical_features
# Out:
# (['age',
#   'ratings',
#   'restaurant_latitude',
#   'restaurant_longitude',
#   'delivery_latitude',
#   'delivery_longitude',
#   'traffic',
#   'vehicle_condition',
#   'multiple_deliveries',
#   'festival',
#   'city_type',
#   'order_day',
#   'order_month',
#   'order_day_of_week',
#   'is_weekend',
#   'pickup_time_minutes',
#   'order_time_hour',
#   'order_time_of_day',
#   'distance'],
#  ['weather_fog',
#   'weather_sandstorms',
#   'weather_stormy',
#   'weather_sunny',
#   'weather_windy',
#   'type_of_order_drinks',
#   'type_of_order_meal',
#   'type_of_order_snack',
#   'type_of_vehicle_electric_scooter',
#   'type_of_vehicle_motorcycle',
#   'type_of_vehicle_scooter'])

# %%
from sklearn.feature_selection import VarianceThreshold

vt = VarianceThreshold(threshold=0.01)
vt.fit(X)

high_variance_features = X.columns[vt.get_support()].tolist()
low_variance_features = X.columns[~vt.get_support()].tolist()

high_variance_features, low_variance_features
# Out:
# (['age',
#   'restaurant_latitude',
#   'delivery_latitude',
#   'traffic',
#   'vehicle_condition',
#   'multiple_deliveries',
#   'festival',
#   'city_type',
#   'order_day',
#   'order_month',
#   'order_day_of_week',
#   'is_weekend',
#   'pickup_time_minutes',
#   'order_time_hour',
#   'order_time_of_day',
#   'distance',
#   'weather_fog',
#   'weather_sandstorms',
#   'weather_stormy',
#   'weather_sunny',
#   'weather_windy',
#   'type_of_order_drinks',
#   'type_of_order_meal',
#   'type_of_order_snack',
#   'type_of_vehicle_electric_scooter',
#   'type_of_vehicle_motorcycle',
#   'type_of_vehicle_scooter'],
#  ['ratings', 'restaurant_longitude', 'delivery_longitude'])

# %%
from sklearn.feature_selection import VarianceThreshold

vt = VarianceThreshold(threshold=0.01)
vt.fit(X)

high_variance_features = X.columns[vt.get_support()].tolist()
low_variance_features = X.columns[~vt.get_support()].tolist()

high_variance_features, low_variance_features
['age',
  'restaurant_latitude',
  'delivery_latitude',
  'traffic',
  'vehicle_condition',
  'multiple_deliveries',
  'festival',
  'city_type',
  'order_day',
  'order_month',
  'order_day_of_week',
  'is_weekend',
  'pickup_time_minutes',
  'order_time_hour',
  'order_time_of_day',
  'distance',
  'weather_fog',
  'weather_sandstorms',
  'weather_stormy',
  'weather_sunny',
  'weather_windy',
  'type_of_order_drinks',
  'type_of_order_meal',
  'type_of_order_snack',
  'type_of_vehicle_electric_scooter',
  'type_of_vehicle_motorcycle',
  'type_of_vehicle_scooter'],
 ['ratings', 'restaurant_longitude', 'delivery_longitude']

# %%
from sklearn.feature_selection import mutual_info_regression
import pandas as pd

mi_scores = mutual_info_regression(X, y, random_state=42)

mi_df = pd.DataFrame({
    "feature": X.columns,
    "mutual_info": mi_scores
}).sort_values(by="mutual_info", ascending=False)

mi_df
# Out:
#                              feature  mutual_info
# 1                            ratings     0.155001
# 16                   order_time_hour     0.129502
# 6                            traffic     0.117512
# 8                multiple_deliveries     0.117286
# 18                          distance     0.088129
# 11                         order_day     0.083886
# 0                                age     0.076505
# 4                  delivery_latitude     0.063275
# 7                  vehicle_condition     0.060347
# 17                 order_time_of_day     0.050413
# 5                 delivery_longitude     0.043026
# 9                           festival     0.042992
# 10                         city_type     0.027486
# 22                     weather_sunny     0.026678
# 29           type_of_vehicle_scooter     0.021727
# 28        type_of_vehicle_motorcycle     0.019069
# 19                       weather_fog     0.008590
# 20                weather_sandstorms     0.005665
# 2                restaurant_latitude     0.005214
# 3               restaurant_longitude     0.005139
# 27  type_of_vehicle_electric_scooter     0.005040
# 21                    weather_stormy     0.004823
# 13                 order_day_of_week     0.002262
# 23                     weather_windy     0.002098
# 26               type_of_order_snack     0.001280
# 24              type_of_order_drinks     0.000797
# 25                type_of_order_meal     0.000071
# 12                       order_month     0.000000
# 15               pickup_time_minutes     0.000000
# 14                        is_weekend     0.000000

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

X_vif = X[numerical_features]

vif_df = pd.DataFrame()
vif_df["feature"] = X_vif.columns
vif_df["VIF"] = [
    variance_inflation_factor(X_vif.values, i)
    for i in range(X_vif.shape[1])
]

vif_df.sort_values(by="VIF", ascending=False)
# Out:
#                  feature           VIF
# 5     delivery_longitude  4.344064e+08
# 3   restaurant_longitude  4.341806e+08
# 4      delivery_latitude  3.329443e+08
# 2    restaurant_latitude  3.309743e+08
# 18              distance  4.646270e+03
# 1                ratings  8.905607e+01
# 12           order_month  3.672848e+01
# 16       order_time_hour  3.340808e+01
# 0                    age  2.926983e+01
# 17     order_time_of_day  2.370224e+01
# 10             city_type  1.807987e+01
# 13     order_day_of_week  8.630656e+00
# 15   pickup_time_minutes  7.196201e+00
# 11             order_day  3.966819e+00
# 14            is_weekend  3.589571e+00
# 8    multiple_deliveries  2.956088e+00
# 6                traffic  2.872345e+00
# 7      vehicle_condition  2.559892e+00
# 9               festival  1.061913e+00

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(
    n_estimators=200,
    random_state=42,
    n_jobs=-1
)

rf.fit(X, y)

importance_df = pd.DataFrame({
    "feature": X.columns,
    "importance": rf.feature_importances_
}).sort_values(by="importance", ascending=False)

importance_df
# Out:
#                              feature  importance
# 1                            ratings    0.197990
# 6                            traffic    0.121789
# 8                multiple_deliveries    0.119466
# 18                          distance    0.097773
# 0                                age    0.095446
# 22                     weather_sunny    0.068822
# 7                  vehicle_condition    0.067327
# 19                       weather_fog    0.031951
# 20                weather_sandstorms    0.018978
# 11                         order_day    0.018017
# 23                     weather_windy    0.017582
# 21                    weather_stormy    0.016703
# 9                           festival    0.015607
# 4                  delivery_latitude    0.015107
# 5                 delivery_longitude    0.014099
# 2                restaurant_latitude    0.013896
# 3               restaurant_longitude    0.012804
# 13                 order_day_of_week    0.010784
# 16                   order_time_hour    0.009123
# 10                         city_type    0.007552
# 15               pickup_time_minutes    0.005964
# 12                       order_month    0.004223
# 25                type_of_order_meal    0.003365
# 17                 order_time_of_day    0.003209
# 26               type_of_order_snack    0.003172
# 24              type_of_order_drinks    0.003099
# 29           type_of_vehicle_scooter    0.001716
# 28        type_of_vehicle_motorcycle    0.001645
# 14                        is_weekend    0.001475
# 27  type_of_vehicle_electric_scooter    0.001317

# %%
from sklearn.inspection import permutation_importance
import pandas as pd

perm = permutation_importance(
    rf,
    X,
    y,
    n_repeats=10,
    random_state=42,
    n_jobs=1   # 🔥 FIX
)

perm_df = pd.DataFrame({
    "feature": X.columns,
    "perm_importance_mean": perm.importances_mean,
    "perm_importance_std": perm.importances_std
}).sort_values(by="perm_importance_mean", ascending=False)

perm_df
# Out:
#                              feature  perm_importance_mean  \
# 6                            traffic              0.457049
# 18                          distance              0.383883
# 1                            ratings              0.367948
# 0                                age              0.328231
# 7                  vehicle_condition              0.280892
# 22                     weather_sunny              0.280273
# 8                multiple_deliveries              0.189307
# 21                    weather_stormy              0.099399
# 23                     weather_windy              0.097554
# 20                weather_sandstorms              0.096097
# 19                       weather_fog              0.078643
# 11                         order_day              0.028754
# 10                         city_type              0.024642
# 4                  delivery_latitude              0.022188
# 9                           festival              0.021648
# 5                 delivery_longitude              0.021441
# 2                restaurant_latitude              0.020106
# 16                   order_time_hour              0.019612
# 3               restaurant_longitude              0.018655
# 13                 order_day_of_week              0.016828
# 15               pickup_time_minutes              0.009609
# 17                 order_time_of_day              0.006191
# 12                       order_month              0.005876
# 25                type_of_order_meal              0.005591
# 26               type_of_order_snack              0.004751
# 24              type_of_order_drinks              0.004419
# 28        type_of_vehicle_motorcycle              0.003089
# 29           type_of_vehicle_scooter              0.002906
# 14                        is_weekend              0.001795
# 27  type_of_vehicle_electric_scooter              0.001442
#
#     perm_importance_std
# 6              0.003922
# 18             0.002481
# 1              0.003067
# 0              0.001768
# 7              0.002667
# 22             0.003172
# 8              0.002004
# 21             0.001297
# 23             0.001160
# 20             0.000925
# 19             0.001092
# 11             0.000237
# 10             0.000384
# 4              0.000093
# 9              0.000658
# 5              0.000090
# 2              0.000121
# 16             0.000258
# 3              0.000091
# 13             0.000180
# 15             0.000073
# 17             0.000202
# 12             0.000141
# 25             0.000071
# 26             0.000053
# 24             0.000057
# 28             0.000043
# 29             0.000041
# 14             0.000027
# 27             0.000030
